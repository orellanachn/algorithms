# %% [markdown]
# <a href="https://colab.research.google.com/github/orellanachn/algorithms/blob/master/fibonacci.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Fibonacci recursivo sin memorización

# %%
def fibonacci(index):
  if index == 0:
    return 0
  elif index == 1 or index== 2:
    return 1
  return fibonacci(index-1)+ fibonacci(index-2)

print(fibonacci(7))
# Out:
# 13

# %% [markdown]
# Fibonacci basado de Dynamic Programming

# %%
def fibonacci_helper(fibonacci_array, index):
  if fibonacci_array[index]>=0:
    return fibonacci_array[index]
  if index == 0:
    return 0
  elif index == 1 or index== 2:
    return 1
  fibonacci_array[index] = fibonacci_helper(fibonacci_array,index - 2) + fibonacci_helper(fibonacci_array, index - 1)
  return fibonacci_array[index]

def fibonacci_DP(index):
  fibonacci_array = [-1]*(index+1)
  return fibonacci_helper(fibonacci_array, index)

print(fibonacci_DP(7))
# Out:
# 13

# %%
import matplotlib.pyplot as plt
import numpy as np
import time as t

times = {}
times_DP = {}

def test(n):
  start_time = t.time()
  print(fibonacci(n))
  times[n]= t.time() - start_time
  print("--- %s seconds ---" % (times[n]))

  start_time = t.time()
  print(fibonacci_DP(n))
  times_DP[n]= t.time() - start_time
  print("--- %s seconds ---" % (times_DP[n]))

def plot(times):
  lists = sorted(times.items())
  x, y = zip(*lists)
  plt.plot(x, y)
  plt.show()
  print(times)

for i in range(50):
  test(i)

plot(times)
plot(times_DP)
# Out:
# 0
# --- 6.103515625e-05 seconds ---
# 0
# --- 1.9550323486328125e-05 seconds ---
# 1
# --- 2.0503997802734375e-05 seconds ---
# 1
# --- 4.649162292480469e-05 seconds ---
# 1
# --- 1.33514404296875e-05 seconds ---
# 1
# --- 1.4781951904296875e-05 seconds ---
# 2
# --- 1.4781951904296875e-05 seconds ---
# 2
# --- 5.6743621826171875e-05 seconds ---
# 3
# --- 2.3603439331054688e-05 seconds ---
# 3
# --- 2.5272369384765625e-05 seconds ---
# 5
# --- 2.47955322265625e-05 seconds ---
# 5
# --- 2.6226043701171875e-05 seconds ---
# 8
# --- 2.3126602172851562e-05 seconds ---
# 8
# --- 1.8358230590820312e-05 seconds ---
# 13
# --- 1.9788742065429688e-05 seconds ---
# 13
# --- 3.695487976074219e-05 seconds ---
# 21
# --- 2.956390380859375e-05 seconds ---
# 21
# --- 2.9802322387695312e-05 seconds ---
# 34
# --- 3.7670135498046875e-05 seconds ---
# 34
# --- 3.0517578125e-05 seconds ---
# 55
# --- 5.459785461425781e-05 seconds ---
# 55
# --- 2.8371810913085938e-05 seconds ---
# 89
# ...
